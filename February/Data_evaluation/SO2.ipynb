# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `chem-obs data`
#
# ---
# *@author: Evan*\
# *@date: 2023-03-29*

# %%
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
ncfile = 'F:/Data/case_anqing/compressed_chem.nc'
var = 'SO2'
varch = 'SO2'

title = '$SO_2$'
units = '$\mu$$g/$$m^3$'

# %% [markdown]
# ## 安庆市全部

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing/Anqing.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/allsite.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the SO2 in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the SO2 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean   7.075779
# 1  sim mean  13.861186
# 2         R   0.305364
# 3        MB   6.785407
# 4      RMSE  10.393248
# 5       IOA   0.180409

# %% [markdown]
# ## 安庆市城区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_urban/urban.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/urban.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the SO2 in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the SO2 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean   7.791741
# 1  sim mean  16.926037
# 2         R   0.322358
# 3        MB   9.134296
# 4      RMSE  13.278276
# 5       IOA   0.218627

# %% [markdown]
# ## 安庆市郊区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/rural.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the SO2 in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the SO2 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean   6.822868
# 1  sim mean  13.465132
# 2         R   0.255824
# 3        MB   6.642264
# 4      RMSE  10.362720
# 5       IOA   0.157200
