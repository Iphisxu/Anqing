# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-03-28*

# %%
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
ncfile = 'F:/Data/case_anqing/compressed_met.nc'
var = 'RH'
varch = '湿度'

title = 'RH'
units = '%'

# %% [markdown]
# ## 安庆市全部

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing/Anqing.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/allsite.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the RH in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 湿度 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  73.263313
# 1  sim mean  62.650398
# 2         R   0.900773
# 3        MB -10.612914
# 4      RMSE  13.912164
# 5       IOA   0.867332

# %% [markdown]
# ## 安庆市城区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_urban/urban.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/urban.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the RH in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 湿度 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  72.594003
# 1  sim mean  61.947186
# 2         R   0.869336
# 3        MB -10.646817
# 4      RMSE  14.584204
# 5       IOA   0.851901

# %% [markdown]
# ## 安庆市郊区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/rural.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the RH in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 湿度 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  73.517571
# 1  sim mean  62.583160
# 2         R   0.890892
# 3        MB -10.934411
# 4      RMSE  14.381687
# 5       IOA   0.860645
