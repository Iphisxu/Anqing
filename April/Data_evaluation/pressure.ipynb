# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `meteo-obs data temperature`
#
# ---
# *@author: Evan*\
# *@date: 2023-05-07*

# %%
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
ncfile = 'F:/Data/case_anqing/April/April_met.nc'
var = 'PRES'
varch = '气压(hPa)'

title = 'Pressure'
units = 'hPa'

# %% [markdown]
# ## 安庆市全部

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing/Anqing.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/allsite.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the PRES in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压(hPa) in shape of (720,)
# data is ready

# %%
start = '2023-04-01T00'
end = '2023-04-30T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param        value
# 0  obs mean  1003.913610
# 1  sim mean   986.372192
# 2         R     0.968665
# 3        MB   -17.541418
# 4      RMSE    17.594227
# 5       IOA     0.393962

# %% [markdown]
# ## 安庆市城区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_urban/urban.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/urban.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the PRES in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压(hPa) in shape of (720,)
# data is ready

# %%
start = '2023-04-01T00'
end = '2023-04-30T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param        value
# 0  obs mean  1008.977076
# 1  sim mean  1007.445984
# 2         R     0.967916
# 3        MB    -1.531093
# 4      RMSE     2.042431
# 5       IOA     0.963048

# %% [markdown]
# 郊区或通道区的范围不好处理，因此以下暂不考虑
# ## 安庆市通道区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/channel.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the PRES in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the 气压 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param        value
# 0  obs mean  1013.459048
# 1  sim mean   996.526123
# 2         R     0.992212
# 3        MB   -16.932925
# 4      RMSE    16.952261
# 5       IOA     0.428745
