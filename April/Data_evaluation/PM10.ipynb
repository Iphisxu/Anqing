# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `chem-obs data`
#
# ---
# *@author: Evan*\
# *@date: 2023-05-09*

# %%
import sys
sys.path.append('../src/')
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
ncfile = 'F:/Data/case_anqing/April/April_chem.nc'
var = 'PM10'
varch = 'PM10'

title = '$PM_{10}$'
units = '$\mu$$g/$$m^3$'

# %% [markdown]
# ## 安庆市全部

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing/Anqing.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/allsite.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the PM10 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the PM10 in shape of (720,)
# data is ready

# %%
start = '2023-04-01T00'
end   = '2023-04-30T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  79.882479
# 1  sim mean  43.159275
# 2         R   0.415383
# 3        MB -36.723204
# 4      RMSE  96.175854
# 5       IOA   0.419319

# %% [markdown]
# ## 安庆市城区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_urban/urban.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/urban.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the PM10 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the PM10 in shape of (720,)
# data is ready

# %%
start = '2023-04-01T00'
end   = '2023-04-30T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param       value
# 0  obs mean   87.361690
# 1  sim mean   48.659706
# 2         R    0.342299
# 3        MB  -38.701984
# 4      RMSE  116.438197
# 5       IOA    0.368568

# %% [markdown]
# ## 安庆市郊区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/rural.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the PM10 in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the PM10 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  61.984278
# 1  sim mean  60.557339
# 2         R   0.565984
# 3        MB  -1.426940
# 4      RMSE  30.911556
# 5       IOA   0.724425
