# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `chem-obs data`
#
# ---
# *@author: Evan*\
# *@date: 2023-05-09*

# %%
import sys
sys.path.append('../src/')
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
ncfile = 'F:/Data/case_anqing/April/April_chem.nc'
var = 'NO'
varch = 'NO'

title = '$NO$'
units = '$\mu$$g/$$m^3$'

# %% [markdown]
# ## 安庆市全部

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing/Anqing.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/allsite.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the NO in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the NO in shape of (720,)
# data is ready

# %%
start = '2023-04-01T00'
end = '2023-04-30T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param     value
# 0  obs mean  3.437403
# 1  sim mean  1.363024
# 2         R  0.097454
# 3        MB -2.074379
# 4      RMSE  4.627514
# 5       IOA  0.355417

# %% [markdown]
# ## 安庆市城区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_urban/urban.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/urban.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the NO in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the NO in shape of (720,)
# data is ready

# %%
start = '2023-04-01T00'
end   = '2023-04-30T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean   4.676204
# 1  sim mean   3.385869
# 2         R   0.001883
# 3        MB  -1.290335
# 4      RMSE  11.887161
# 5       IOA   0.196997

# %% [markdown]
# ## 安庆市郊区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/rural.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the NO2 in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the NO2 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  24.228991
# 1  sim mean  27.333508
# 2         R   0.047702
# 3        MB   3.104517
# 4      RMSE  16.031115
# 5       IOA   0.365598
