# %% [markdown]
# # 安徽安庆市项目`WRF-CMAQ`模拟分析
# ## Model Evaluation : `chem-obs data`
#
# ---
# *@author: Evan*\
# *@date: 2023-05-09*

# %%
import sys
sys.path.append('../src/')
import ModelEvaLib as me

import matplotlib.pyplot as plt

# silence the warning note
import warnings
warnings.filterwarnings("ignore")

# %%
ncfile = 'F:/Data/case_anqing/April/April_chem.nc'
var = 'O3'
varch = 'O3'

title = '$O_3$'
units = '$\mu$$g/$$m^3$'

# %% [markdown]
# ## 安庆市全部

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing/Anqing.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/allsite.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the O3 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the O3 in shape of (720,)
# data is ready

# %%
start = '2023-04-01T00'
end = '2023-04-30T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param       value
# 0  obs mean   76.873522
# 1  sim mean  112.950119
# 2         R    0.551913
# 3        MB   36.076597
# 4      RMSE   55.660326
# 5       IOA    0.623586

# %% [markdown]
# ## 安庆市城区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_urban/urban.shp'
xlsfile = 'F:/Data/case_anqing/April/obsdata/urban.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the O3 in shape of (720, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the O3 in shape of (720,)
# data is ready

# %%
start = '2023-04-01T00'
end = '2023-04-30T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Urban Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  77.624028
# 1  sim mean  95.877190
# 2         R   0.489961
# 3        MB  18.253162
# 4      RMSE  53.484054
# 5       IOA   0.655361

# %% [markdown]
# ## 安庆市郊区

# %%
shpfile = 'F:/Data/case_anqing/shapefile/Anqing_rural/rural.shp'
xlsfile = 'F:/Data/case_anqing/obs_202302_fromlzj/rural.xlsx'

df, sim, obs = me.get_var(ncfile,var,shpfile,xlsfile,varch)
# Out:
# Get the O3 in shape of (672, 138, 135)
# Extract the data within the boundary ...
# Finish
# Get the O3 in shape of (672,)
# data is ready

# %%
start = '2023-02-01T00'
end = '2023-02-28T23'

ax = me.linechart(sim, obs, start, end)

ax.legend(loc=2)
ax.set_title(f'{title} in Rural Anqing')
ax.set_xlabel('Date')
ax.set_ylabel(units)
plt.show()

# %%
me.evaluation_frame(obs, sim, df)
# Out:
#       param      value
# 0  obs mean  50.643102
# 1  sim mean  48.283783
# 2         R   0.253583
# 3        MB  -2.359319
# 4      RMSE  32.383070
# 5       IOA   0.561202
